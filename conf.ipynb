# %%
import sqlite3
import pandas as pd
import plotly.express as px

# %%
# !pip3 install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
DB_PATH = '/home/aubrey/Desktop/Guam07-training-set/code/active_learning2.sqlite3'

# %%
df = pd.read_sql_query('SELECT COUNT(*) AS n, AVG(conf) FROM obj GROUP BY cls;', sqlite3.connect(DB_PATH))
df
# Out:
#        n  AVG(conf)
# 0   3409   0.642117
# 1  11974   0.676188
# 2   2494   0.632066
# 3    588   0.654735
# 4    241   0.453592
# 5   4422   0.460527

# %%
sql = 'SELECT * FROM obj WHERE cls=0;'
df = pd.read_sql_query(sql, sqlite3.connect(DB_PATH))
fig = px.histogram(df, x="conf", cumulative=True, title=sql)
fig.show()

# %%
sql = 'SELECT * FROM obj WHERE cls=1;'
df = pd.read_sql_query(sql, sqlite3.connect(DB_PATH))
fig = px.histogram(df, x="conf", cumulative=True, title=sql)
fig.show()

# %%
sql = 'SELECT * FROM obj WHERE cls=2;'
df = pd.read_sql_query(sql, sqlite3.connect(DB_PATH))
fig = px.histogram(df, x="conf", cumulative=True, title=sql)
fig.show()

# %%
sql = 'SELECT * FROM obj WHERE cls=3;'
df = pd.read_sql_query(sql, sqlite3.connect(DB_PATH))
fig = px.histogram(df, x="conf", cumulative=True, title=sql)
fig.show()

# %%
sql = 'SELECT * FROM obj WHERE cls=4;'
df = pd.read_sql_query(sql, sqlite3.connect(DB_PATH))
fig = px.histogram(df, x="conf", cumulative=True, title=sql)
fig.show()

# %%
sql = 'SELECT * FROM obj WHERE cls=5;'
df = pd.read_sql_query(sql, sqlite3.connect(DB_PATH))
fig = px.histogram(df, x="conf", cumulative=True, title=sql)
fig.show()
